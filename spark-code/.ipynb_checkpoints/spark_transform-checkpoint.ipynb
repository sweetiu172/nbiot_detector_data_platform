# %%
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import input_file_name, regexp_extract, lit

# --- 1. Configure Spark Session ---
spark = (
    SparkSession.builder.appName("IoT_Botnet_Transformation")
    .master("local[*]")
    .config("spark.driver.memory", "4g")
    .config("spark.hadoop.fs.s3a.endpoint", "http://minio:9000")
    .config("spark.hadoop.fs.s3a.access.key", "minio_access_key")
    .config("spark.hadoop.fs.s3a.secret.key", "minio_secret_key")
    .config("spark.hadoop.fs.s3a.path.style.access", True)
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
    .config("spark.jars.packages", "io.delta:delta-spark_2.12:3.2.0,org.apache.hadoop:hadoop-aws:3.3.4")
    .getOrCreate()
)
print("Spark session created successfully!")
# Out:
# Spark session created successfully!

# %%
# --- 2. Read and Transform Data ---
raw_path = "s3a://iot-time-series/raw_data/*/*.csv"

# Read all CSVs. Using input_file_name() lets us extract info from the path.
df = spark.read.option("header", "true").option("inferSchema", "true").csv(raw_path)

# Extract device name and attack type from the file path
# The path looks like: s3a://raw/Danmini_Doorbell/benign_traffic.csv
path_regex = r"s3a:\/\/iot-time-series\/(.*?)/(.*?)\/(.*?.csv)"
df = df.withColumn("filePath", input_file_name())
df = df.withColumn("device", regexp_extract("filePath", path_regex, 1))
df = df.withColumn("label", regexp_extract("filePath", path_regex, 2))
df = df.withColumn("label", regexp_extract("label", r"(.*?)_.*", 1)) # Extract attack name, e.g., 'benign' or 'gafgyt'
df = df.drop("filePath")

df.printSchema()
df.select("device", "label").show(5)
# Out:
# root
#  |-- MI_dir_L5_weight: double (nullable = true)
#  |-- MI_dir_L5_mean: double (nullable = true)
#  |-- MI_dir_L5_variance: double (nullable = true)
#  |-- MI_dir_L3_weight: double (nullable = true)
#  |-- MI_dir_L3_mean: double (nullable = true)
#  |-- MI_dir_L3_variance: double (nullable = true)
#  |-- MI_dir_L1_weight: double (nullable = true)
#  |-- MI_dir_L1_mean: double (nullable = true)
#  |-- MI_dir_L1_variance: double (nullable = true)
#  |-- MI_dir_L0.1_weight: double (nullable = true)
#  |-- MI_dir_L0.1_mean: double (nullable = true)
#  |-- MI_dir_L0.1_variance: double (nullable = true)
#  |-- MI_dir_L0.01_weight: double (nullable = true)
#  |-- MI_dir_L0.01_mean: double (nullable = true)
#  |-- MI_dir_L0.01_variance: double (nullable = true)
#  |-- H_L5_weight: double (nullable = true)
#  |-- H_L5_mean: double (nullable = true)
#  |-- H_L5_variance: double (nullable = true)
#  |-- H_L3_weight: double (nullable = true)
#  |-- H_L3_mean: double (nullable = true)
#  |-- H_L3_variance: double (nullable = true)
#  |-- H_L1_weight: double (nullable = true)
#  |-- H_L1_mean: double (nullable = true)
#  |-- H_L1_variance: double (nullable = true)
#  |-- H_L0.1_weight: double (nullable = true)
#  |-- H_L0.1_mean: double (nullable = true)
#  |-- H_L0.1_variance: double (nullable = true)
#  |-- H_L0.01_weight: double (nullable = true)
#  |-- H_L0.01_mean: double (nullable = true)
#  |-- H_L0.01_variance: double (nullable = true)
#  |-- HH_L5_weight: double (nullable = true)
#  |-- HH_L5_mean: double (nullable = true)
#  |-- HH_L5_std: double (nullable = true)
#  |-- HH_L5_magnitude: double (nullable = true)
#  |-- HH_L5_radius: double (nullable = true)
#  |-- HH_L5_covariance: double (nullable = true)
#  |-- HH_L5_pcc: double (nullable = true)
#  |-- HH_L3_weight: double (nullable = true)
#  |-- HH_L3_mean: double (nullable = true)
#  |-- HH_L3_std: double (nullable = true)
#  |-- HH_L3_magnitude: double (nullable = true)
#  |-- HH_L3_radius: double (nullable = true)
#  |-- HH_L3_covariance: double (nullable = true)
#  |-- HH_L3_pcc: double (nullable = true)
#  |-- HH_L1_weight: double (nullable = true)
#  |-- HH_L1_mean: double (nullable = true)
#  |-- HH_L1_std: double (nullable = true)
#  |-- HH_L1_magnitude: double (nullable = true)
#  |-- HH_L1_radius: double (nullable = true)
#  |-- HH_L1_covariance: double (nullable = true)
#  |-- HH_L1_pcc: double (nullable = true)
#  |-- HH_L0.1_weight: double (nullable = true)
#  |-- HH_L0.1_mean: double (nullable = true)
#  |-- HH_L0.1_std: double (nullable = true)
#  |-- HH_L0.1_magnitude: double (nullable = true)
#  |-- HH_L0.1_radius: double (nullable = true)
#  |-- HH_L0.1_covariance: double (nullable = true)
#  |-- HH_L0.1_pcc: double (nullable = true)
#  |-- HH_L0.01_weight: double (nullable = true)
#  |-- HH_L0.01_mean: double (nullable = true)
#  |-- HH_L0.01_std: double (nullable = true)
#  |-- HH_L0.01_magnitude: double (nullable = true)
#  |-- HH_L0.01_radius: double (nullable = true)
#  |-- HH_L0.01_covariance: double (nullable = true)
#  |-- HH_L0.01_pcc: double (nullable = true)
#  |-- HH_jit_L5_weight: double (nullable = true)
#  |-- HH_jit_L5_mean: double (nullable = true)
#  |-- HH_jit_L5_variance: double (nullable = true)
#  |-- HH_jit_L3_weight: double (nullable = true)
#  |-- HH_jit_L3_mean: double (nullable = true)
#  |-- HH_jit_L3_variance: double (nullable = true)
#  |-- HH_jit_L1_weight: double (nullable = true)
#  |-- HH_jit_L1_mean: double (nullable = true)
#  |-- HH_jit_L1_variance: double (nullable = true)
#  |-- HH_jit_L0.1_weight: double (nullable = true)
#  |-- HH_jit_L0.1_mean: double (nullable = true)
#  |-- HH_jit_L0.1_variance: double (nullable = true)
#  |-- HH_jit_L0.01_weight: double (nullable = true)
#  |-- HH_jit_L0.01_mean: double (nullable = true)
#  |-- HH_jit_L0.01_variance: double (nullable = true)
#  |-- HpHp_L5_weight: double (nullable = true)
#  |-- HpHp_L5_mean: double (nullable = true)
#  |-- HpHp_L5_std: double (nullable = true)
#  |-- HpHp_L5_magnitude: double (nullable = true)
#  |-- HpHp_L5_radius: double (nullable = true)
#  |-- HpHp_L5_covariance: double (nullable = true)
#  |-- HpHp_L5_pcc: double (nullable = true)
#  |-- HpHp_L3_weight: double (nullable = true)
#  |-- HpHp_L3_mean: double (nullable = true)
#  |-- HpHp_L3_std: double (nullable = true)
#  |-- HpHp_L3_magnitude: double (nullable = true)
#  |-- HpHp_L3_radius: double (nullable = true)
#  |-- HpHp_L3_covariance: double (nullable = true)
#  |-- HpHp_L3_pcc: double (nullable = true)
#  |-- HpHp_L1_weight: double (nullable = true)
#  |-- HpHp_L1_mean: double (nullable = true)
#  |-- HpHp_L1_std: double (nullable = true)
#  |-- HpHp_L1_magnitude: double (nullable = true)
#  |-- HpHp_L1_radius: double (nullable = true)
#  |-- HpHp_L1_covariance: double (nullable = true)
#  |-- HpHp_L1_pcc: double (nullable = true)
#  |-- HpHp_L0.1_weight: double (nullable = true)
#  |-- HpHp_L0.1_mean: double (nullable = true)
#  |-- HpHp_L0.1_std: double (nullable = true)
#  |-- HpHp_L0.1_magnitude: double (nullable = true)
#  |-- HpHp_L0.1_radius: double (nullable = true)
#  |-- HpHp_L0.1_covariance: double (nullable = true)
#  |-- HpHp_L0.1_pcc: double (nullable = true)
#  |-- HpHp_L0.01_weight: double (nullable = true)
#  |-- HpHp_L0.01_mean: double (nullable = true)
#  |-- HpHp_L0.01_std: double (nullable = true)
#  |-- HpHp_L0.01_magnitude: double (nullable = true)
#  |-- HpHp_L0.01_radius: double (nullable = true)
#  |-- HpHp_L0.01_covariance: double (nullable = true)
#  |-- HpHp_L0.01_pcc: double (nullable = true)
#  |-- device: string (nullable = false)
#  |-- label: string (nullable = false)
#
# +--------+-------+
# |  device|  label|
# +--------+-------+
# |raw_data|Philips|
# |raw_data|Philips|
# |raw_data|Philips|
# |raw_data|Philips|
# |raw_data|Philips|
# +--------+-------+
# only showing top 5 rows

# %%
# --- 3. Write to Delta Lake format ---
processed_path = "s3a://processed/iot_botnet_data"

# Save the DataFrame as a Delta table, overwriting if it already exists
df.write.format("delta").mode("overwrite").save(processed_path)

print(f"Successfully wrote data to Delta table at: {processed_path}")
# Out:
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/usr/local/spark/python/pyspark/errors/exceptions/captured.py", line 179, in deco
#     return f(*a, **kw)
#            ^^^^^^^^^^^
#   File "/usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/protocol.py", line 326, in get_return_value
#     raise Py4JJavaError(
# py4j.protocol.Py4JJavaError: <exception str() failed>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# File /usr/local/spark/python/pyspark/errors/exceptions/captured.py:179, in capture_sql_exception.<locals>.deco(*a, **kw)
#     178 try:
# --> 179     return f(*a, **kw)
#     180 except Py4JJavaError as e:
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/protocol.py:326, in get_return_value(answer, gateway_client, target_id, name)
#     325 if answer[1] == REFERENCE_TYPE:
# --> 326     raise Py4JJavaError(
#     327         "An error occurred while calling {0}{1}{2}.\n".
#     328         format(target_id, ".", name), value)
#     329 else:
#
# <class 'str'>: (<class 'ConnectionRefusedError'>, ConnectionRefusedError(111, 'Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# Py4JError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       2 processed_path = "s3a://processed/iot_botnet_data"
#       4 # Save the DataFrame as a Delta table, overwriting if it already exists
# ----> 5 df.write.format("delta").mode("overwrite").save(processed_path)
#       7 print(f"Successfully wrote data to Delta table at: {processed_path}")
#
# File /usr/local/spark/python/pyspark/sql/readwriter.py:1463, in DataFrameWriter.save(self, path, format, mode, partitionBy, **options)
#    1461     self._jwrite.save()
#    1462 else:
# -> 1463     self._jwrite.save(path)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/spark/python/pyspark/errors/exceptions/captured.py:181, in capture_sql_exception.<locals>.deco(*a, **kw)
#     179     return f(*a, **kw)
#     180 except Py4JJavaError as e:
# --> 181     converted = convert_exception(e.java_exception)
#     182     if not isinstance(converted, UnknownException):
#     183         # Hide where the exception came from that shows a non-Pythonic
#     184         # JVM exception message.
#     185         raise converted from None
#
# File /usr/local/spark/python/pyspark/errors/exceptions/captured.py:173, in convert_exception(e)
#     167     msg = (
#     168         "\n  An exception was thrown from the Python worker. "
#     169         "Please see the stack trace below.\n%s" % c.getMessage()
#     170     )
#     171     return PythonException(msg, stacktrace)
# --> 173 return UnknownException(desc=e.toString(), stackTrace=stacktrace, cause=c)
#
# File /usr/local/spark/python/pyspark/errors/exceptions/captured.py:65, in CapturedException.__init__(self, desc, stackTrace, cause, origin)
#      59 assert SparkContext._jvm is not None
#      60 self.stackTrace = (
#      61     stackTrace
#      62     if stackTrace is not None
#      63     else (SparkContext._jvm.org.apache.spark.util.Utils.exceptionString(origin))
#      64 )
# ---> 65 self.cause = convert_exception(cause) if cause is not None else None
#      66 if self.cause is None and origin is not None and origin.getCause() is not None:
#      67     self.cause = convert_exception(origin.getCause())
#
# File /usr/local/spark/python/pyspark/errors/exceptions/captured.py:139, in convert_exception(e)
#     137     return QueryExecutionException(origin=e)
#     138 # Order matters. NumberFormatException inherits IllegalArgumentException.
# --> 139 elif is_instance_of(gw, e, "java.lang.NumberFormatException"):
#     140     return NumberFormatException(origin=e)
#     141 elif is_instance_of(gw, e, "java.lang.IllegalArgumentException"):
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:464, in is_instance_of(gateway, java_object, java_class)
#     460 else:
#     461     raise Py4JError(
#     462         "java_class must be a string, a JavaClass, or a JavaObject")
# --> 464 return gateway.jvm.py4j.reflection.TypeUtil.isInstanceOf(
#     465     param, java_object)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1725, in JVMView.__getattr__(self, name)
#    1722 _, error_message = get_error_message(answer)
#    1723 message = compute_exception_message(
#    1724     "{0} does not exist in the JVM".format(name), error_message)
# -> 1725 raise Py4JError(message)
#
# Py4JError: py4j does not exist in the JVM
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
